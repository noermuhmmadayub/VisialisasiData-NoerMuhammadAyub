# %% [markdown]
# ## Praktikum 7 -  Horizontal Bar Chart dan Staacked Horizontal Bar Chart

# %% [markdown]
# #### **KELOMPOK 28**
#
#
# *   Muhammad Ayub (NIM: 12345678)
# *   Rahmi Atika (NIM: 0110222279)
# *   Saskia Putri Ananda (NIM: 0110222159)

# %% [markdown]
# # 1.Import Library

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 2. Daataset

# %%
# Data Penjualan
brands = ['Samsung', 'Iphone', 'Vivo', 'Oppo']
sales_2023 = [500, 700, 300, 400]
sales_2024 = [550, 750, 350, 450]
sales_2025 = [600, 800, 400, 500]

# %% [markdown]
# # 3. Basic Chart (Horizontal & Stacked Horizontal Bar Cgart)

# %%
y_pos = np.arange(len(brands))

# Canvas dan axis grafis
fig1, ax1, = plt.subplots()

# garafik batang horizontal
ax1.set_title('Horizontal Bar Chart = 2023')
ax1.set_xlabel('Jumlah Penjualan')
ax1.set_ylabel('Merk')
ax1.barh(brands, sales_2024)
plt.show()

#stacked horizotal bar chart
#canvas and axis grafis
fig2, ax2, = plt.subplots()

#garafik batang horizontal
ax2.set_title('Stacked Horizontal Bar Chart - 2023 & 2024')
ax2.set_xlabel('Jumlah Penjualan')
ax2.set_ylabel('Merk')

# bart pertama untuk 2023
ax2.barh(brands, sales_2023, label='2023')

# bart kedua untuk 2025
ax2.barh(brands, sales_2024, left=sales_2023, label='2024')

#legend
ax2.legend()
plt.show()

# %% [markdown]
# # 4. Kustomisasi Grafik

# %%
y_pos = np.arange(len(brands))
colors = ['gold', 'skyblue', 'coral', 'lightgreen']

#custom horizontal bar chart (2023)
fig3, ax3 = plt.subplots()

ax3.barh(brands, sales_2023, color=colors, edgecolor='black', height=0.6)
ax3.set_title('Penjualan Smartphone Tahun 2023 (custom)')
ax3.set_xlabel('Jumlah Penjualan')
ax3.set_ylabel('Merk')
ax3.grid(axis='x', linestyle='--', alpha=0.7)

#Menampilkan label nilai di bar chart
for i, v in enumerate(sales_2023):
    ax3.text(v+10, i, str(v), color='black')

plt.show()

#custom horizontal bar chart (2023) - (2024)
fig4, ax4 = plt.subplots()

ax4.barh(brands, sales_2023, color='lightcoral', edgecolor='black', label='2023')
ax4.barh(brands, sales_2024, left=sales_2023, color='lightskyblue', edgecolor='black', height=0.8)

ax4.set_title('Penjualan Smartphone Tahun 2023 & 2024 (custom)')
ax4.set_xlabel('Jumlah Penjualan')
ax4.set_ylabel('Merk')
ax4.grid(axis='x', linestyle='--', alpha=0.5)

#Hitung total penjualan dari 2 tahun untuk label angka
total_sales = np.array(sales_2023) + np.array(sales_2024) + np.array(sales_2025)

#Menampilkan label nilai di bar char
for i, v in enumerate(total_sales):
    ax4.text(v+10, i, str(v), va= 'center')

plt.show()

# %% [markdown]
# # 5. Multiple Chart

# %%
y_pos = np.arange(len(brands))

# Multiple horizontal Bar Chart
fig5, ax5 = plt.subplots()

# bar pertama
ax5.barh(y_pos - 0.2, sales_2023, color='skyblue', height=0.4, label='2023')

# bar kedua
ax5.barh(y_pos + 0.2, sales_2023, color='salmon', height=0.4, label='2024')

ax5.set_title('Penjualan Smarthphone Tahun 2023 vs 2024 (custom)')
ax5.set_xlabel('Jumlah Penjualan')
ax5.set_ylabel('Merk')
ax5.set_yticks(y_pos, brands)
ax5.legend()
plt.show()

# Multiple stacked horizontal Bar Chart
fig6, ax6 = plt.subplots()

# bar pertama
ax6.barh(y_pos, sales_2023, color='skyblue', label='2023')
# bar kedua
ax6.barh(y_pos, sales_2024, left=sales_2023, color='salmon', label='2024')
#bar ketiga
ax6.barh(y_pos, sales_2025, left=np.array(sales_2023) + np.array (sales_2024),color='lightgreen', label='2025')


ax6.set_title('Penjualan Smarthphone Tahun 2023 vs 2024 (Stacked)')
ax6.set_xlabel('Jumlah Penjualan')
ax6.set_ylabel('Merk')
ax6.set_yticks(y_pos, brands)
ax6.legend()
plt.show()
